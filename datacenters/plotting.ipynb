# %%
import pandas as pd

df = pd.read_csv('geo_data_centers_cleaned.csv')
df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df
# Out:
#                             name      country               city  \
# 0             EXA Infrastructure  switzerland             Geneva
# 1                         NexTDC    australia           Perth WA
# 2                       OVHCloud          usa     Virginia 20187
# 3                       LeaseWeb      germany   Kalbach-Riedberg
# 4                     Amazon AWS          usa                 VA
# ...                          ...          ...                ...
# 3273                  rne Global           uk             London
# 3274  Iron Mountain Data Centers          usa                 NJ
# 3275  Iron Mountain Data Centers  netherlands            Haarlem
# 3276                     Telstra    singapore           Tai Seng
# 3277              Digital Realty          usa                 VA
#
#                            town                         address  \
# 0                   1217 Meyrin         Chemin de l'Epinglier 2
# ...

# %%
power_df = df[df['total power (MW)'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3278 entries, 0 to 3277
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     3278 non-null   object
#  1   country                  3278 non-null   object
#  2   city                     3276 non-null   object
#  3   town                     3124 non-null   object
#  4   address                  2409 non-null   object
#  5   total space (sqft)       2019 non-null   object
#  6   colocation space (sqft)  1260 non-null   object
#  7   total power (MW)         1467 non-null   object
#  8   latitude                 3260 non-null   float64
#  9   longitude                3260 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 256.2+ KB
